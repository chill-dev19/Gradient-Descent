# %% [markdown]
# <a href="https://colab.research.google.com/github/chill-dev19/Gradient-Descent/blob/main/Gradient_Descent.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"></a>

# %% [markdown]
# # Gradient Descent
#
# Gradient Descent is the most basic but most used optimization algorithm. It's used heavily in linear regression and classification algorithms. It is an iterative optimisation algorithm to find the minimum of a function.

# %% [markdown]
# Gradient descent is an optimization algorithm used to find the values of parameters (coefficients) of a function (f) that minimizes a cost function (cost). Parameters refer to coefficients in linear regression and weights in neural networks.

# %% [markdown]
# # Batch Gradient Descent

# %% [markdown]
# BGD is a variation of the gradient descent algorithm that calculates the error for each example in the training datasets, but only updates the model after all training examples have been evaluated.

# %% [markdown]
# Example:
#
# * Number of epochs = 10
# * Number of samples in training dataset = 50
# * Model gets updated when all 50 samples are evaluated
# * 50 samples = 1 batch; entire dataset
# * After 1 epoch 1 update takes place, After 10 epochs 10 updates takes place
# * 1 * 10 = 10 updates takes place in batch gradient descent

# %% [markdown]
# # Stochastic Gradient Descent

# %% [markdown]
# SGD is a variation of the gradient descent that calculates the error and updates the model for each record in the training datasets.

# %% [markdown]
# Example:
#
# * Number of epochs = 10
# * Number of samples in training dataset = 50
# * Model gets updated after every sample evaluation
# * After 1 epoch 50 updates takes place because there are 50 samples, After 10 epochs 500 updates takes place
# * 50 * 10 = 500 updates takes place in Stochastic gradient descent

# %% [markdown]
# # Mini Batch Gradient Descent (MGD)

# %% [markdown]
# MGD is a variation of the gradient descent algorithm that splits the training datasets into small batches that are used to calculate model error and update model coefficients.

# %% [markdown]
# Example:
#
# * Number of epochs = 10
# * Number of samples in training dataset = 50
# * Each batch have 10 samples so there are total 5 batches
# * Model gets updated after every batch evaluation
# * After 1 epoch 5 updates takes place because there are 5 batches containing 10 samples each, After 10 epochs 50 updates takes place
# * 5 * 10 = 50 updates takes place in Mini Batch gradient descent

# %% [markdown]
# ## Order in terms of speed:
#
# Batch Gradient Descent > Mini Batch Gradient Descent > Stochastic Gradient Descent

# %% [markdown]
# # Batch vs Stochastic

# %% [markdown]
# ## Batch Gradient Descent (BGD)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv('Social_Network_Ads.csv')
df.head()

# %%
df = df.drop(['User ID', 'Gender'], axis=1)

# %%
df

# %%
X = df.iloc[:,0:2]

# %%
Y = df.iloc[:,-1]

# %%
X
